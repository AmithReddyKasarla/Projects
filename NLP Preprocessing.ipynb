# %% [markdown]
# # NLP Text Preprocessing using Word2Vec

# %%
# !pip install gensim

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
#taking predefined dataset from google news
import gensim.downloader as api

# %%
gg = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vec_men = gg['men']

# %%
vec_men
# Out:
# array([-4.78515625e-02,  1.66992188e-01,  7.81250000e-02,  2.10571289e-03,
#         2.25585938e-01, -2.25585938e-01, -2.09960938e-01, -3.73535156e-02,
#        -1.85546875e-02,  1.94335938e-01, -3.00292969e-02, -1.77734375e-01,
#         5.20019531e-02,  1.33789062e-01, -1.13769531e-01,  1.10351562e-01,
#        -3.27148438e-02,  2.89916992e-03,  9.88769531e-03,  9.27734375e-02,
#        -2.19726562e-01, -2.47802734e-02, -8.59375000e-02, -2.67578125e-01,
#        -2.51464844e-02, -2.55859375e-01, -1.61132812e-01,  2.53906250e-01,
#         5.24902344e-02, -1.00097656e-02,  1.82617188e-01,  7.61718750e-02,
#        -1.60980225e-03, -3.10058594e-02, -3.32031250e-02,  1.81640625e-01,
#        -3.88183594e-02, -1.83593750e-01, -8.64257812e-02,  2.20703125e-01,
#        -7.11059570e-03,  8.60595703e-03,  1.73828125e-01, -9.27734375e-02,
#         1.25000000e-01, -1.28906250e-01, -4.85839844e-02, -1.21093750e-01,
# ...

# %%
gg.similarity('women','men')
# Out:
# 0.7674937

# %%
gg.most_similar('women')
# Out:
# [('men', 0.767493724822998),
#  ('Women', 0.7283449769020081),
#  ('womens', 0.6786179542541504),
#  ('girls', 0.633903980255127),
#  ('females', 0.6240421533584595),
#  ('mothers', 0.6050933599472046),
#  ('ladies', 0.5865179300308228),
#  ('husbands', 0.5705341696739197),
#  ('transwomen', 0.5697940587997437),
#  ('Men', 0.5693342089653015)]

# %%
new_vec= gg['men']+gg['women']-gg['female']

# %%
new_vec
# Out:
# array([-0.07080078,  0.2788086 ,  0.07226562,  0.26626587,  0.49169922,
#        -0.20605469, -0.26879883, -0.18896484, -0.1586914 ,  0.22558594,
#        -0.02416992, -0.26123047, -0.03881836,  0.26367188, -0.08679199,
#         0.2783203 , -0.02880859,  0.12643433, -0.00924683,  0.25268555,
#        -0.46533203,  0.10632324,  0.03759766, -0.42578125,  0.12036133,
#        -0.2861328 , -0.01953125,  0.10839844, -0.3010254 , -0.20715332,
#        -0.01515198,  0.3125    , -0.04457855, -0.09936523, -0.03881836,
#         0.3701172 , -0.15966797, -0.47070312, -0.16516113,  0.16601562,
#        -0.03982544,  0.11798096,  0.3720703 , -0.34033203,  0.12536621,
#        -0.18334961, -0.23852539, -0.15478516,  0.25593567,  0.06201172,
#         0.48583984,  0.20654297,  0.08844757, -0.0045166 ,  0.14550781,
#        -0.69921875, -0.09231567, -0.03434181, -0.3461914 , -0.00299072,
#        -0.03442383,  0.09597778, -0.11010742, -0.05632019,  0.20040894,
# ...
